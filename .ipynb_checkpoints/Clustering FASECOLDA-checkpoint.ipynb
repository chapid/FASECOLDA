# %%
import pandas as pd
my_dataset = pd.read_csv("ExamenFinal.csv",sep=",")
my_dataset = my_dataset.drop(['FECHA_NACIMIENTO','GENERO','ESTADO_CIVIL','NUMERO_HIJOS','PROFESION','NIVEL_ESTUDIO','OCUPACION','SERVICIO','KILOMETRAJE_INSTALACION','FECHA_LICENCIA','RELACION_ASEGURADO','COLOR','CIUDAD','MARCA','CLASE','TIPO'],axis=1)

# %%
my_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             602 non-null    int64
#  1   Edad                           602 non-null    float64
#  2   TIEMPO_PROPIETARIO             602 non-null    int64
#  3   Edad Licencia                  602 non-null    float64
#  4   CILINDRAJE                     602 non-null    int64
#  5   Min(Recorrido (Km))            602 non-null    int64
#  6   Min(Frenadas (Uni))            602 non-null    int64
#  7   Min(Arrancadas (Uni))          602 non-null    int64
#  8   Min(Aceleraciones (Uni))       602 non-null    int64
#  9   Min(Exceso Velocidad (Min))    602 non-null    int64
#  10  Min(Maxima Velocidad (Km/h))   602 non-null    float64
#  11  Min(Tiempo Uso (Min))          602 non-null    int64
# ...

# %%
my_dataset.fillna(0)
# Out:
#            id   Edad  TIEMPO_PROPIETARIO  Edad Licencia  CILINDRAJE  \
# 0    43665400  72.38                   5          55.18        2300
# 1    60342217  35.93                   7           9.15        1300
# 2    16205257  81.04                  10          61.55        2500
# 3    42188664  38.46                   5          11.10        2500
# 4    93966068  70.30                   6          37.19        2000
# ..        ...    ...                 ...            ...         ...
# 597  86038652  56.09                   4          13.85        1200
# 598  80355353  48.42                   9          25.42        2000
# 599  43184833  46.10                   2           7.65        1300
# 600  80786094  53.38                   2          25.44        2500
# 601  87568396  34.67                  12          13.67        2500
#
#      Min(Recorrido (Km))  Min(Frenadas (Uni))  Min(Arrancadas (Uni))  \
# 0                      1                    0                      0
# ...

# %% [markdown]
# #### Búsqueda de cantidad óptima de clusters

# %%
wcss = []
for i in range (1,11):
    kmeans = KMeans(n_clusters = i, max_iter = 300)
    kmeans.fit(my_dataset)
    wcss.append(kmeans.inertia_)
